# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
def get_jobs(category, pages = 99):
    '''Gets scrapes the job title, company name, location, views and skills'''
    job_list = []
    pages += 1
    for no in range(1,pages):
        # goes through the given number of pages
        url = "https://merojob.com/category/" + category + "/?page="+ str(no)
        r = requests.get(url)
        soup = bs(r.content, 'html.parser')
        jobs = soup.find_all('div',attrs={"class": "card mt-3 hover-shadow"})
        try:
            for x in range(0,6):
                # extracting data
                job_title = jobs[x].find(itemprop="title").get_text(" ", strip=True)
                orgn = orgn = jobs[x].find('h3',attrs={"class": "h6"}).get_text(" ", strip=True)
                location = jobs[x].find(itemprop="address").get_text(" ", strip=True)
                views = jobs[x].find('span',attrs={'class':'text-primary mr-2'}).get_text(" ", strip=True).replace("Views: ","")
                try:
                    desc = jobs[x].find(itemprop="skills").get_text(", ", strip=True)
                except:
                    desc = ("No skills listed")

                # adding data to list

                job_list.append({"Job Title" : job_title,
                "Company" : orgn,
                "Location" : location,
                "Views" : int(views),
                "Skills" : desc})
        except:
            return pd.DataFrame(job_list)#changes the list into a pandas dataframe
    return pd.DataFrame(job_list)#changes the list into a pandas dataframe

# %%
it = get_jobs("it-telecommunication")#catagory and page number
(it)
# Out:
#                            Job Title  \
# 0                Software Developers
# 1   Support and Implementation Engi…
# 2           Software Engineer (Java)
# 3                  Flutter Developer
# 4                 Software Developer
# 5          Daraz Future Leaders 2023
# 6          Associate Project Manager
# 7               Enterprise Architect
# 8                Compliance Engineer
# 9                Principal Architect
# 10  Senior Software Engineer (Pytho…
# 11  Senior Quality Assurance Engine…
# 12   Technical Writer (Customer Suc…
# 13            Senior DevOps Engineer
# 14               Engineering Manager
# 15               Java Lead Developer
# 16  Software Development Engineer i…
# 17                     Lead Engineer
# 18              Software Engineer II
# 19                 Node JS Developer
# 20                    Java Developer
# 21              Senior PHP Developer
# 22       QA Automation Test Engineer
# 23  Search Engine Optimisation (SEO…
# 24                 Database Engineer
# 25                      IT Assistant
# 26                IT Support Interns
# 27                     PHP Developer
# 28                 Node.js Developer
# 29                  Graphic Designer
# 30                      Web Designer
# 31       Digital Marketing Executive
# 32  Senior React Front End Developer
# 33                Senior QA Engineer
# 34            Senior DevOps Engineer
# 35                        Senior DBA
# 36  Content Writer (Statistics/Acco…
# 37       Lead Cloud Systems Engineer
# 38   Jr. Frontend developer React JS
# 39              Jr. Python Developer
# 40             Mid Level UI Designer
# 41                   DevOps Engineer
# 42                 Laravel Developer
#
#                                               Company  \
# 0                        Clusus Information Solutions
# 1                        Clusus Information Solutions
# 2                                 Cedar Gate Services
# 3                                             Merojob
# 4                         Shailung Group of Companies
# 5                                               Daraz
# 6                                 Cedar Gate Services
# 7                                      COTIVITI NEPAL
# 8                                 Cedar Gate Services
# 9                                      COTIVITI NEPAL
# 10                                     Logpoint Nepal
# 11                                     Logpoint Nepal
# 12                                     Logpoint Nepal
# 13                                     Logpoint Nepal
# 14                                     Logpoint Nepal
# 15                                            Infoxit
# 16                                      UBA Solutions
# 17                                      UBA Solutions
# 18                                      UBA Solutions
# 19                                     Sterling Wells
# 20                                Smart Data Solution
# 21                                     Proshore Nepal
# 22  Fairlawn Information Technonology Resource Pvt...
# 23                    Versatile Information Solutions
# 24                           Nyaya Health Nepal (NHN)
# 25                                          HLE Nepal
# 26                              Synergy Tech Software
# 27                               Nepsol Web Solutions
# 28                                  Omega Outsourcing
# 29                                         ThemeGrill
# 30                                              View9
# 31                                      Susankya Tech
# 32                                     Pagodalabs.com
# 33                                     Pagodalabs.com
# 34                                     Pagodalabs.com
# 35                                     Pagodalabs.com
# 36                               InditeSmith Offshore
# 37                                     Aqore Software
# 38                               Diyo.A.I. Technology
# 39                               Diyo.A.I. Technology
# 40                               Diyo.A.I. Technology
# 41                                            12iD AB
# 42                                      Megabyte Tech
#
#                                              Location  Views  \
# 0                       Jhamsikhel-2, Lalitpur, Nepal   1161
# 1                       Jhamsikhel-2, Lalitpur, Nepal   1367
# 2                                    Kathmandu, Nepal   1075
# 3                                    Kathmandu, Nepal    769
# 4                                           Kathmandu    461
# 5                                           Kathmandu   2626
# 6                                    Kathmandu, Nepal   1152
# 7                                    Kathmandu, Nepal    478
# 8                                    Kathmandu, Nepal    633
# 9                                    Kathmandu, Nepal    358
# 10                               Jawalakhel ,Lalitpur    370
# 11                               Jawalakhel ,Lalitpur    217
# 12                               Jawalakhel ,Lalitpur    379
# 13                               Jawalakhel ,Lalitpur    394
# 14                               Jawalakhel ,Lalitpur    651
# 15                Butwal , Kathmandu (Work from Home)    499
# 16                           Imadole, Lalitpur, Nepal    180
# 17                           Imadole, Lalitpur, Nepal    104
# 18                           Imadole, Lalitpur, Nepal    131
# 19                                 Tinkune, Kathmandu     88
# 20                                  Lalitpur , remote    238
# 21                                                       163
# 22                               Baneshwor, Kathmandu    609
# 23                                     Work from home    169
# 24                                          Kathmandu    311
# 25                                           Lalitpur    756
# 26                                           Pulchowk    442
# 27                                                       132
# 28                                   Kathmandu, Nepal    154
# 29                            Basundhara-3, Kathmandu     74
# 30                               Sankhamul, Kathmandu    756
# 31                                   Kathmandu, Nepal    162
# 32                                           Lalitpur    162
# 33                                   Sanepa, Lalitpur    110
# 34                                           Lalitpur     74
# 35                                           lalitpur    151
# 36  Paryag Marg,Shantinagar,Kathmandu(near Babylon...    295
# 37                                      New Baneshwor    154
# 38                                   Jwagal, lalitpur    279
# 39                                   Jwagal, lalitpur    196
# 40                                   Jwagal, lalitpur     87
# 41  4th Floor, IT Plaza, Kamaladi, Kathmandu 44600...    350
# 42                              Bhagwati Marga, Naxal    204
#
#                                                Skills
# 0          Teamwork, Time Management, Problem Solving
# 1   Interpersonal, Communication, Teamwork, Custom...
# 2                                    No skills listed
# 3          Teamwork, Time Management, Problem Solving
# 4                                    No skills listed
# 5   Management, Communication, Data Analysis, Exce...
# 6                                    No skills listed
# 7          Communication, Analytical, Time Management
# 8                                    No skills listed
# 9          Communication, Analytical, Time Management
# 10                                   No skills listed
# 11                                   No skills listed
# 12                                   No skills listed
# 13                                   No skills listed
# 14             Leadership, Communication, Negotiation
# 15  Hibernet, Spring Boot, Rest, Tomcat, Docker, J...
# 16          Automation, Selenium, Javascript, Cypress
# 17      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js
# 18      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js
# 19  Time Management, Problem Solving, Databases, S...
# 20           Jquery, Css, Javascript, Core Java, J2Ee
# 21          Mvc, Symphony, Cms, Html, Css, Javascript
# 22      Software Testing Life Cycle, Javascript, Java
# 23  Google Strategy, Optimizing Website Performanc...
# 24                                   No skills listed
# 25                                   No skills listed
# 26  Interpersonal, Leadership, Communication, Cust...
# 27                 Information Management, Web Design
# 28   Html, Javascript, Css3, Html5, Node.Js Developer
# 29  Illustration, Photoshop, Creative Thinking, Pr...
# 30  Javascript, Angular, Ui/Ux, React.Js, Jquery, ...
# 31  Interpersonal, Marketing, Digital Marketing, M...
# 32                              React, Api, Html, Css
# 33                   Software Quality Assurance, Java
# 34               Problem-Solving Skills, Python, Java
# 35                  Postgres, Database Administration
# 36  Communication, Copywriter, Content Writing, Wr...
# 37  Critical Thinking, Communication, Cloud Applic...
# 38                                 Node.Js, Html, Css
# 39  Team Spirit, Communication, Javascript, Proble...
# 40            Javascript, Ui Design Skills, Html, Css
# 41                    Containerization, Devops, Linux
# 42                                   No skills listed

# %%
it.head(10)
# Out:
#                           Job Title                       Company  \
# 0               Software Developers  Clusus Information Solutions
# 1  Support and Implementation Engi…  Clusus Information Solutions
# 2          Software Engineer (Java)           Cedar Gate Services
# 3                 Flutter Developer                       Merojob
# 4                Software Developer   Shailung Group of Companies
# 5         Daraz Future Leaders 2023                         Daraz
# 6         Associate Project Manager           Cedar Gate Services
# 7              Enterprise Architect                COTIVITI NEPAL
# 8               Compliance Engineer           Cedar Gate Services
# 9               Principal Architect                COTIVITI NEPAL
#
#                         Location  Views  \
# 0  Jhamsikhel-2, Lalitpur, Nepal   1161
# 1  Jhamsikhel-2, Lalitpur, Nepal   1367
# 2               Kathmandu, Nepal   1075
# 3               Kathmandu, Nepal    769
# 4                      Kathmandu    461
# 5                      Kathmandu   2626
# 6               Kathmandu, Nepal   1152
# 7               Kathmandu, Nepal    478
# 8               Kathmandu, Nepal    633
# 9               Kathmandu, Nepal    358
#
#                                               Skills
# 0         Teamwork, Time Management, Problem Solving
# 1  Interpersonal, Communication, Teamwork, Custom...
# 2                                   No skills listed
# 3         Teamwork, Time Management, Problem Solving
# 4                                   No skills listed
# 5  Management, Communication, Data Analysis, Exce...
# 6                                   No skills listed
# 7         Communication, Analytical, Time Management
# 8                                   No skills listed
# 9         Communication, Analytical, Time Management

# %%
it.loc[it.Views.idxmax()]
# Out:
# Job Title                            Daraz Future Leaders 2023
# Company                                                  Daraz
# Location                                             Kathmandu
# Views                                                     2626
# Skills       Management, Communication, Data Analysis, Exce...
# Name: 5, dtype: object

# %%
it.nlargest(10,['Views'])
# Out:
#                            Job Title                       Company  \
# 5          Daraz Future Leaders 2023                         Daraz
# 1   Support and Implementation Engi…  Clusus Information Solutions
# 0                Software Developers  Clusus Information Solutions
# 6          Associate Project Manager           Cedar Gate Services
# 2           Software Engineer (Java)           Cedar Gate Services
# 3                  Flutter Developer                       Merojob
# 25                      IT Assistant                     HLE Nepal
# 30                      Web Designer                         View9
# 14               Engineering Manager                Logpoint Nepal
# 8                Compliance Engineer           Cedar Gate Services
#
#                          Location  Views  \
# 5                       Kathmandu   2626
# 1   Jhamsikhel-2, Lalitpur, Nepal   1367
# 0   Jhamsikhel-2, Lalitpur, Nepal   1161
# 6                Kathmandu, Nepal   1152
# 2                Kathmandu, Nepal   1075
# 3                Kathmandu, Nepal    769
# 25                       Lalitpur    756
# 30           Sankhamul, Kathmandu    756
# 14           Jawalakhel ,Lalitpur    651
# 8                Kathmandu, Nepal    633
#
#                                                Skills
# 5   Management, Communication, Data Analysis, Exce...
# 1   Interpersonal, Communication, Teamwork, Custom...
# 0          Teamwork, Time Management, Problem Solving
# 6                                    No skills listed
# 2                                    No skills listed
# 3          Teamwork, Time Management, Problem Solving
# 25                                   No skills listed
# 30  Javascript, Angular, Ui/Ux, React.Js, Jquery, ...
# 14             Leadership, Communication, Negotiation
# 8                                    No skills listed

# %%
it.nsmallest(10,['Views'])
# Out:
#                  Job Title               Company                  Location  \
# 29        Graphic Designer            ThemeGrill   Basundhara-3, Kathmandu
# 34  Senior DevOps Engineer        Pagodalabs.com                  Lalitpur
# 40   Mid Level UI Designer  Diyo.A.I. Technology          Jwagal, lalitpur
# 19       Node JS Developer        Sterling Wells        Tinkune, Kathmandu
# 17           Lead Engineer         UBA Solutions  Imadole, Lalitpur, Nepal
# 33      Senior QA Engineer        Pagodalabs.com          Sanepa, Lalitpur
# 18    Software Engineer II         UBA Solutions  Imadole, Lalitpur, Nepal
# 27           PHP Developer  Nepsol Web Solutions
# 35              Senior DBA        Pagodalabs.com                  lalitpur
# 28       Node.js Developer     Omega Outsourcing          Kathmandu, Nepal
#
#     Views                                             Skills
# 29     74  Illustration, Photoshop, Creative Thinking, Pr...
# 34     74               Problem-Solving Skills, Python, Java
# 40     87            Javascript, Ui Design Skills, Html, Css
# 19     88  Time Management, Problem Solving, Databases, S...
# 17    104      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js
# 33    110                   Software Quality Assurance, Java
# 18    131      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js
# 27    132                 Information Management, Web Design
# 35    151                  Postgres, Database Administration
# 28    154   Html, Javascript, Css3, Html5, Node.Js Developer

# %%
it.to_csv('it-telecommunication.csv')

# %%
fin = get_jobs("accounting-finance")
sec = get_jobs("general-mgmt-administration-operations")

# %%
fin.nsmallest(10,['Views'])
# Out:
#                            Job Title                                 Company  \
# 8                         Accountant           Hamro Hastakala Bikri Bhandar
# 13                        Accountant                             A.R.B.NEPAL
# 17  Corporate Project Accountant So…                      Swisscontact Nepal
# 16                 Compliance Ecpert                                    ADRA
# 11     Finance & Admin-Asst. Manager                         Tech One Global
# 12         Finance and Admin Officer                            Relief Nepal
# 6   JR. Officer/Officer (Microfinan…  Royal Multipurpose Cooperative Limited
# 10                        Accountant       Moon Rock International Pvt. Ltd.
# 15                        Accountant                    KTM Consulting Group
# 14                        Accountant                         Moresco Trading
#
#                                              Location  Views  \
# 8                                           Kathmandu    200
# 13                                          Kathmandu    219
# 17                                                       228
# 16                                                       246
# 11                             Bishalnagar, Kathmandu    338
# 12                                                       377
# 6   Pharping, Tokha, Basundhara, Budhanilkantha, S...    438
# 10                               Anamnagar, Kathmandu    484
# 15                             Shorakhutte, Kathmandu    625
# 14                                          Kathmandu    876
#
#                                                Skills
# 8   Interpersonal, Communication, Time Management,...
# 13  Taxation, Excel, Accounting, Financial Forecas...
# 17                                   No skills listed
# 16                                   No skills listed
# 11  Organizational, Teamwork, Problem Solving, Ana...
# 12                                   No skills listed
# 6   Interpersonal, Management, Communication, Time...
# 10                                   No skills listed
# 15  Interpersonal, Management, Organizational, Acc...
# 14  Account Management, Communication, Analytical,...

# %%
fin_views = it['Views'].sum()
it_views = fin['Views'].sum()
sec_views = sec['Views'].sum()
total_views = {'Category': ['IT', 'Finance', 'Secretary'], 'Total Views': [it_views, fin_views, sec_views ]}

# %%
Tviews = pd.DataFrame(total_views)
Tviews
# Out:
#     Category  Total Views
# 0         IT        18640
# 1    Finance        19121
# 2  Secretary        41378

# %%
it['Python'] = it.apply(lambda x: 1 if 'PYTHON' in x['Skills'].upper() or 'PYTHON' in x['Job Title'].upper() else 0, axis=1)
it
# Out:
#                            Job Title  \
# 0                Software Developers
# 1   Support and Implementation Engi…
# 2           Software Engineer (Java)
# 3                  Flutter Developer
# 4                 Software Developer
# 5          Daraz Future Leaders 2023
# 6          Associate Project Manager
# 7               Enterprise Architect
# 8                Compliance Engineer
# 9                Principal Architect
# 10  Senior Software Engineer (Pytho…
# 11  Senior Quality Assurance Engine…
# 12   Technical Writer (Customer Suc…
# 13            Senior DevOps Engineer
# 14               Engineering Manager
# 15               Java Lead Developer
# 16  Software Development Engineer i…
# 17                     Lead Engineer
# 18              Software Engineer II
# 19                 Node JS Developer
# 20                    Java Developer
# 21              Senior PHP Developer
# 22       QA Automation Test Engineer
# 23  Search Engine Optimisation (SEO…
# 24                 Database Engineer
# 25                      IT Assistant
# 26                IT Support Interns
# 27                     PHP Developer
# 28                 Node.js Developer
# 29                  Graphic Designer
# 30                      Web Designer
# 31       Digital Marketing Executive
# 32  Senior React Front End Developer
# 33                Senior QA Engineer
# 34            Senior DevOps Engineer
# 35                        Senior DBA
# 36  Content Writer (Statistics/Acco…
# 37       Lead Cloud Systems Engineer
# 38   Jr. Frontend developer React JS
# 39              Jr. Python Developer
# 40             Mid Level UI Designer
# 41                   DevOps Engineer
# 42                 Laravel Developer
#
#                                               Company  \
# 0                        Clusus Information Solutions
# 1                        Clusus Information Solutions
# 2                                 Cedar Gate Services
# 3                                             Merojob
# 4                         Shailung Group of Companies
# 5                                               Daraz
# 6                                 Cedar Gate Services
# 7                                      COTIVITI NEPAL
# 8                                 Cedar Gate Services
# 9                                      COTIVITI NEPAL
# 10                                     Logpoint Nepal
# 11                                     Logpoint Nepal
# 12                                     Logpoint Nepal
# 13                                     Logpoint Nepal
# 14                                     Logpoint Nepal
# 15                                            Infoxit
# 16                                      UBA Solutions
# 17                                      UBA Solutions
# 18                                      UBA Solutions
# 19                                     Sterling Wells
# 20                                Smart Data Solution
# 21                                     Proshore Nepal
# 22  Fairlawn Information Technonology Resource Pvt...
# 23                    Versatile Information Solutions
# 24                           Nyaya Health Nepal (NHN)
# 25                                          HLE Nepal
# 26                              Synergy Tech Software
# 27                               Nepsol Web Solutions
# 28                                  Omega Outsourcing
# 29                                         ThemeGrill
# 30                                              View9
# 31                                      Susankya Tech
# 32                                     Pagodalabs.com
# 33                                     Pagodalabs.com
# 34                                     Pagodalabs.com
# 35                                     Pagodalabs.com
# 36                               InditeSmith Offshore
# 37                                     Aqore Software
# 38                               Diyo.A.I. Technology
# 39                               Diyo.A.I. Technology
# 40                               Diyo.A.I. Technology
# 41                                            12iD AB
# 42                                      Megabyte Tech
#
#                                              Location  Views  \
# 0                       Jhamsikhel-2, Lalitpur, Nepal   1161
# 1                       Jhamsikhel-2, Lalitpur, Nepal   1367
# 2                                    Kathmandu, Nepal   1075
# 3                                    Kathmandu, Nepal    769
# 4                                           Kathmandu    461
# 5                                           Kathmandu   2626
# 6                                    Kathmandu, Nepal   1152
# 7                                    Kathmandu, Nepal    478
# 8                                    Kathmandu, Nepal    633
# 9                                    Kathmandu, Nepal    358
# 10                               Jawalakhel ,Lalitpur    370
# 11                               Jawalakhel ,Lalitpur    217
# 12                               Jawalakhel ,Lalitpur    379
# 13                               Jawalakhel ,Lalitpur    394
# 14                               Jawalakhel ,Lalitpur    651
# 15                Butwal , Kathmandu (Work from Home)    499
# 16                           Imadole, Lalitpur, Nepal    180
# 17                           Imadole, Lalitpur, Nepal    104
# 18                           Imadole, Lalitpur, Nepal    131
# 19                                 Tinkune, Kathmandu     88
# 20                                  Lalitpur , remote    238
# 21                                                       163
# 22                               Baneshwor, Kathmandu    609
# 23                                     Work from home    169
# 24                                          Kathmandu    311
# 25                                           Lalitpur    756
# 26                                           Pulchowk    442
# 27                                                       132
# 28                                   Kathmandu, Nepal    154
# 29                            Basundhara-3, Kathmandu     74
# 30                               Sankhamul, Kathmandu    756
# 31                                   Kathmandu, Nepal    162
# 32                                           Lalitpur    162
# 33                                   Sanepa, Lalitpur    110
# 34                                           Lalitpur     74
# 35                                           lalitpur    151
# 36  Paryag Marg,Shantinagar,Kathmandu(near Babylon...    295
# 37                                      New Baneshwor    154
# 38                                   Jwagal, lalitpur    279
# 39                                   Jwagal, lalitpur    196
# 40                                   Jwagal, lalitpur     87
# 41  4th Floor, IT Plaza, Kamaladi, Kathmandu 44600...    350
# 42                              Bhagwati Marga, Naxal    204
#
#                                                Skills  Python
# 0          Teamwork, Time Management, Problem Solving       0
# 1   Interpersonal, Communication, Teamwork, Custom...       0
# 2                                    No skills listed       0
# 3          Teamwork, Time Management, Problem Solving       0
# 4                                    No skills listed       0
# 5   Management, Communication, Data Analysis, Exce...       0
# 6                                    No skills listed       0
# 7          Communication, Analytical, Time Management       0
# 8                                    No skills listed       0
# 9          Communication, Analytical, Time Management       0
# 10                                   No skills listed       0
# 11                                   No skills listed       0
# 12                                   No skills listed       0
# 13                                   No skills listed       0
# 14             Leadership, Communication, Negotiation       0
# 15  Hibernet, Spring Boot, Rest, Tomcat, Docker, J...       0
# 16          Automation, Selenium, Javascript, Cypress       0
# 17      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js       0
# 18      Html5, Css3, Node.Js, Ci/Cd, Veu.Js, React.Js       0
# 19  Time Management, Problem Solving, Databases, S...       0
# 20           Jquery, Css, Javascript, Core Java, J2Ee       0
# 21          Mvc, Symphony, Cms, Html, Css, Javascript       0
# 22      Software Testing Life Cycle, Javascript, Java       0
# 23  Google Strategy, Optimizing Website Performanc...       0
# 24                                   No skills listed       0
# 25                                   No skills listed       0
# 26  Interpersonal, Leadership, Communication, Cust...       0
# 27                 Information Management, Web Design       0
# 28   Html, Javascript, Css3, Html5, Node.Js Developer       0
# 29  Illustration, Photoshop, Creative Thinking, Pr...       0
# 30  Javascript, Angular, Ui/Ux, React.Js, Jquery, ...       0
# 31  Interpersonal, Marketing, Digital Marketing, M...       0
# 32                              React, Api, Html, Css       0
# 33                   Software Quality Assurance, Java       0
# 34               Problem-Solving Skills, Python, Java       1
# 35                  Postgres, Database Administration       0
# 36  Communication, Copywriter, Content Writing, Wr...       0
# 37  Critical Thinking, Communication, Cloud Applic...       0
# 38                                 Node.Js, Html, Css       0
# 39  Team Spirit, Communication, Javascript, Proble...       1
# 40            Javascript, Ui Design Skills, Html, Css       0
# 41                    Containerization, Devops, Linux       0
# 42                                   No skills listed       0
