# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
url = "https://merojob.com/category/it-telecommunication/?page="
r = requests.get(url)
soup = bs(r.content)
content = soup.prettify()
print(content)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    IT Jobs in Nepal | Career in IT | merojob
#   </title>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="Find out the latest job vacancies and careers in IT at  merojob.com. Register your profile, and apply for IT jobs in nepal for free!!!" name="description"/>
#   <meta content="IT Jobs, IT jobs in nepal, vacancy in IT, job vacancy in IT company, jobs in IT companies, job vacancy in IT companies, PHP developer job, php programmer jobs, php programming jobs, content writing jobs, online content writing jobs, IT job vacancies, IT graduate jobs " name="keywords"/>
#   <meta content="merojob" name="author"/>
#   <meta content="KVzb1w4KL9v9xYDmCb-NYo9d0jRnm4e4cirTwVM9lfY" name="google-site-verification"/>
# ...

# %%
jobs = soup.find('div',attrs={'id':'search_job'})
print(jobs.prettify)
# Out:
# <bound method Tag.prettify of <div class="" id="search_job">
# <span class="d-none" id="filter-job-count">5</span>
# <div class="card mt-3 hover-shadow" itemscope="" itemtype="http://schema.org/JobPosting">
# <div class="card-body">
# <a class="ui right corner badge">
# <i class="icon-top-job icon text-success"></i>
# </a>
# <div class="row job-card text-center text-lg-left">
# <div class="col-4 col-md-3 col-lg-3 p-1 text-center" itemprop="hiringOrganization" itemscope="" itemtype="http://schema.org/Organization">
# <meta content="Smart Data Solution" itemprop="name"/>
# <img alt="Smart Data Solution" class="border p-1" itemprop="image" src="/media/cache/e1/a2/e1a277cb0f5aaf74f618035072348d9b.jpg"/>
# </div>
# <div class="col-8 col-lg-9 col-md-9 pl-3 pl-md-0 text-left">
# <h1 class="text-primary font-weight-bold media-heading h4" itemprop="title">
# <a href="/ux-designer-team-lead/" title="UX Designer -Team Lead">
# UX Designer -Team Lead
# </a>
# ...

# %%
job_title = jobs.find_all(itemprop="title")[4].get_text(" ", strip=True)
print(job_title)
# Out:
# WordPress Developer / Php Devel…

# %%
orgn = jobs.select('h3.h6')[1]
print(orgn)
# Out:
# <h3 class="h6" title="Cedar Gate Services">
# <a class="text-dark" href="/employer/cedar-gate-services-pvt-ltd/">
# Cedar Gate Services
# </a>
# </h3>

# %%
location = jobs.find_all(itemprop="address")[2].get_text(" ", strip=True)
print(location)
# Out:
# Work From Home , Remotely

# %%
views = jobs.find_all('span',attrs={'class':'text-primary mr-2'})[2].get_text(" ", strip=True).replace("Views: ","")
print(int(views))
# Out:
# 805

# %%
try:
    desc = jobs.find_all(itemprop="skills")[1].get_text(" ", strip=True).split(" ")
except:
    print("No skills listed")

# %%
for x in range(0,5):
            print(x)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(desc)
# Out:
# ['Jquery', 'Css', 'Javascript', 'J2Ee', 'Java']

# %%
url = "https://merojob.com/category/it-telecommunication/?page=4"
r = requests.get(url)
job_list = []
soup = bs(r.content)
jobs = soup.find('div',attrs={'id':'search_job'})
for x in range(0,5):
            
            # extracting data
            
    job_title = jobs.find_all(itemprop="title")[x].get_text(" ", strip=True)
    orgn = jobs.select('h3.h6')[x].get_text(" ", strip=True)
    location = jobs.find_all(itemprop="address")[x].get_text(" ", strip=True)
    views = jobs.find_all('span',attrs={'class':'text-primary mr-2'})[x].get_text(" ", strip=True).replace("Views: ","")
    try:
        desc = jobs.find_all(itemprop="skills")[x].get_text(" ", strip=True).split(" ")
    except:
        desc = ("No skills listed")
                
            # adding data to list
            
    job_list.append({"Job Title" : job_title,
    "Company" : orgn,
    "Location" : location,
    "Views" : views,
    "Skills" : desc})
pd.DataFrame(job_list)
# Out:
#                           Job Title              Company  \
# 0        Backend Developer (Python)            Tekvortex
# 1          Software Engineer (.NET)  Cedar Gate Services
# 2                 Software Engineer       Hitachi Energy
# 3  Associate Client Support Specia…       Hitachi Energy
# 4                  NodeJS Developer       HiUp Solutions
#
#                                    Location Views  \
# 0                      Jhamsikhel, Lalitpur   115
# 1                          Kathmandu, Nepal   200
# 2   Kathmandu , Sitapaila, Kathmandu, Nepal   132
# 3                                 Kathmandu   251
# 4  Narayan Chour, Naxal-1, Kathmandu, Nepal    12
#
#                                               Skills
# 0  [Php, Multi, Tasker, Documentation, Team, Play...
# 1  [Interpersonal, Video, Editing, Communication,...
# 2                                   No skills listed
# 3                                   No skills listed
# ...
